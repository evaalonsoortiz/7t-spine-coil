# %% [markdown]
# <a href="https://colab.research.google.com/github/evaalonsoortiz/7t-spine-coil/blob/main/7t_spine_coil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/evaalonsoortiz/7t-spine-coil
% cd 7t-spine-coil
# Out:
# Cloning into '7t-spine-coil'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 50 (delta 3), reused 50 (delta 3), pack-reused 0
# Unpacking objects: 100% (50/50), done.
# /content/7t-spine-coil/7t-spine-coil

# %%
# !pip install sigpy h5py

import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

# %%
img = nib.load('TFL_SAG_2MMISO_384MM_REFV_0008/TFL_SAG_2MMISO_384MM_REFV_0008_tfl_sag_2mmISO_384mm_REFV_20210408113743_8.nii')

# %%
data = img.get_fdata()
data.shape
imgplot = plt.imshow(np.rot90(data[:,:,28]))
imgplot.set_cmap('gray')
plt.axis('off')
plt.colorbar()
plt.clim(0,900)
plt.show()
